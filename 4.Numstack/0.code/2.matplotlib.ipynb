# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,20,5)
y= np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.xlabel("input")
plt.ylabel("output")
plt.title("function")
plt.plot(x,y);
